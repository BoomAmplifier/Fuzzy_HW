# %% [markdown]
# # **Project 8 for Fuzzy System**
#
# > Instructor: Dr. Hao Ying
# > **Solutions given by Yuqi Wang**
# > Email: he1173@wayne.edu
# > Date: 04.08.2022
#
# ## Descriptions
# - Source codes will be uploaded and updated to [Github repo](https://github.com/BoomAmplifier/Fuzzy_HW).
# - *Matlab* is licenced by WSU.
# - *Jupyter Notebook* and *python3* are also used in the document.

# %% [markdown]
# ## Project 8
# The Matlab code for Project8 is in the attached file `YQ_FS_p8.mlx`. The results are as follows in short.
#
# - 1. 2 clusters, m=2 (i.e., expo=2), iterateration=200, improve=1e-5
#
# <div>
# <left>
#     <img src=".\fig\p8-1.svg" style="width: 50%;height: 50%"/>
# </left>
# </div>
#
# - 2.1. 3 clusters, m=1.1, iterateration=200, improve=1e-5
#
# <div>
# <left>
#     <img src=".\fig\p8-2.svg" style="width: 50%;height: 50%"/>
# </left>
# </div>
#
# - 2.2. 3 clusters, m=2, iterateration=200, improve=1e-5
#
# <div>
# <left>
#     <img src=".\fig\p8-3.svg" style="width: 50%;height: 50%"/>
# </left>
# </div>
#
# - 2.3. 3 clusters, m=3, iterateration=200, improve=1e-5
#
# <div>
# <left>
#     <img src=".\fig\p8-4.svg" style="width: 50%;height: 50%"/>
# </left>
# </div>
#
#
# The average maximum membership value, averageMax, provides a quantitative description of the overlap. The points marked black `x` in the above 3 pictures have maximum membership values below 0.6. These points have a greater degree of uncertainty in their cluster membership.
#
# By comprision among the 3 figures, more overlap and more uncertain data points appear when fuzzy partition matrix exponents `m` increases.
#
#
#
#
# - 3. 2 clusters, m=2, iterateration=200, improve=1e-5, data set is the table
#
# <div>
# <left>
#     <img src=".\fig\p8-5.svg" style="width: 50%;height: 50%"/>
# </left>
# </div>
