# %% [markdown]
# # **Project 6 for Fuzzy System**
#
# > Instructor: Dr. Hao Ying
# > **Solutions given by Yuqi Wang**
# > Email: he1173@wayne.edu
# > Date: 03.01.2022
#
# ## Descriptions
# - Source codes will be uploaded and updated to [Github repo](https://github.com/BoomAmplifier/Fuzzy_HW).
# - *Matlab* is licenced by WSU.
# - *Jupyter Notebook* and *python3* are also used in the document.

# %% [markdown]
# ## Project 6
# The system is
# $$\begin{equation}
# \begin{array}{}
# f(x)=e^{\frac{x}{2}}\sin{x} && x\in[0,6.5]
# \end{array}
# \end{equation}$$

# %% [markdown]
# ## Solutions:

# %% [markdown]
# STEP1: Generate 100 points of equal distance for $(x,f)$.
# STEP2: Chose 70 points for training data set, 15 points for validation, and 15 points for testing within Neural Network Toolbox.
#
# <div>
# <center>
#    <img src=".\fig\p6-1.jpg" style="width: 40%;height: 40%"/>
# </center>
# </div>
#
# STEP3: Generate a neural network with a hidden layer of 3 neuros.
#
# <div>
# <center>
#    <img src=".\fig\p6-2.jpg" style="width: 50%;height: 50%"/>
# </center>
# </div>
#
# STEP4: Train the neural network by using Levenberg-Marquardt method.
#
#
# <div>
# <center>
#    <img src=".\fig\p6-3.jpg" style="width: 80%;height: 80%"/>
# </center>
# </div>
#
# <div>
# <center>
#    <img src=".\fig\p6-4.jpg" style="width: 50%;height: 50%"/>
# </center>
# </div>
#
# <div>
# <center>
#    <img src=".\fig\p6-5.jpg" style="width: 60%;height: 60%"/>
# </center>
# </div>

# %% [markdown]
# The weights and biases of the designed neural network are shown as follows.
# $$\begin{equation}
# \begin{array}{lcl}
# W^1 &=&
# \begin{bmatrix}
# -2.1830497888700937104 \\ -1.719212398074219772 \\ -1.7938970319048990198
# \end{bmatrix}^T \\
# b^1 &=&
# \begin{bmatrix}
# 2.5769500169305588066\\0.66674259779246591862\\-0.91222943224312547095
# \end{bmatrix}\\
# W^2 &=&
# \begin{bmatrix}
# -6.3871060467039368902 \\ 2.4779547928655034639 \\ -0.59983346666094283783
# \end{bmatrix}^T \\
# b^2 &=& 4.7371088939721186506 \\
# f^1 &=& \frac{2}{1+e^{-2n^1}} - 1\\
# f^2 &=& \rm{purelin}(n^2)
# \end{array}
# \end{equation}$$
